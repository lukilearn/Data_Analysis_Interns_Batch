# %%
import pandas as pd

# %%
nba=pd.read_csv('nba.csv')
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
# we are going to find ranking of all the players


nba.shape
# Out:
# (458, 9)

# %%
nba.isna().sum()
# Out:
# Name         1
# Team         1
# Number       1
# Position     1
# Age          1
# Height       1
# Weight       1
# College     85
# Salary      12
# dtype: int64

# %%
nba.dropna(how='all')
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba.shape
# Out:
# (458, 9)

# %%
nba["Salary"]=nba["Salary"].fillna(0)

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        0.0
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
# to type cast the data :

nba["Salary"]=nba["Salary"].fillna(0).astype(int)

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0
# 3      Georgia State  1148640
# 4                NaN  5000000

# %%
nba["Salary"].rank()
# Out:
# 0      362.0
# 1      349.0
# 2        6.5
# 3      137.0
# 4      312.0
#        ...
# 453    218.0
# 454     76.0
# 455    244.5
# 456     92.0
# 457      6.5
# Name: Salary, Length: 458, dtype: float64

# %%
nba["Salary"].rank(ascending=False).astype(int)
# Out:
# 0       97
# 1      110
# 2      452
# 3      322
# 4      147
#       ...
# 453    241
# 454    383
# 455    214
# 456    367
# 457    452
# Name: Salary, Length: 458, dtype: int32

# %%
nba["SalaryRank"]=nba["Salary"].rank(ascending=False).astype(int)

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College   Salary  SalaryRank
# 0              Texas  7730337          97
# 1          Marquette  6796117         110
# 2  Boston University        0         452
# 3      Georgia State  1148640         322
# 4                NaN  5000000         147

# %%
nba["Salary"].idxmax()
# Out:
# 109

# %%
nba.loc[105:110,"Salary":"SalaryRank"]
# Out:
#        Salary  SalaryRank
# 105   1159680         319
# 106   3000000         210
# 107    845059         393
# 108    700000         404
# 109  25000000           1
# 110    845059         393

# %%
#another way


nba.sort_values(by='Salary',ascending=False)
# Out:
#                 Name                    Team  Number Position   Age Height  \
# 109      Kobe Bryant      Los Angeles Lakers    24.0       SF  37.0    6-6
# 169     LeBron James     Cleveland Cavaliers    23.0       SF  31.0    6-8
# 33   Carmelo Anthony         New York Knicks     7.0       SF  32.0    6-8
# 251    Dwight Howard         Houston Rockets    12.0        C  30.0   6-11
# 339       Chris Bosh              Miami Heat     1.0       PF  32.0   6-11
# ..               ...                     ...     ...      ...   ...    ...
# 269     Ray McCallum       Memphis Grizzlies     5.0       PG  24.0    6-3
# 409       Greg Smith  Minnesota Timberwolves     4.0       PF  25.0   6-10
# 2       John Holland          Boston Celtics    30.0       SG  27.0    6-5
# 264    Jordan Farmar       Memphis Grizzlies     4.0       PG  29.0    6-2
# 457              NaN                     NaN     NaN      NaN   NaN    NaN
#
#      Weight            College    Salary  SalaryRank
# ...

# %% [markdown]
# # Filtering Data Frame in Pandas

# %%
import pandas as pd
df=pd.read_csv('employees.csv')
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 39.1+ KB

# %% [markdown]
# ### from the above info() it show wrong data object for some columns

# %%
df["Start Date"].head()  # wrong datatype showing as object but actual datatype is timedate format
# Out:
# 0     8/6/1993
# 1    3/31/1996
# 2    4/23/1993
# 3     3/4/2005
# 4    1/24/1998
# Name: Start Date, dtype: object

# %% [markdown]
# ### above "Start Date" column is not date data type it shows object its totally wrong we have to change the datatype

# %%
pd.to_datetime(df["Start Date"])  # convert normal date to timedate format
# Out:
# 0     1993-08-06
# 1     1996-03-31
# 2     1993-04-23
# 3     2005-03-04
# 4     1998-01-24
#          ...
# 995   2014-11-23
# 996   1984-01-31
# 997   2013-05-20
# 998   2013-04-20
# 999   2012-05-15
# Name: Start Date, Length: 1000, dtype: datetime64[ns]

# %%
df["Start Date"]=pd.to_datetime(df["Start Date"])

# %%
df.head()
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2022-03-23 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2022-03-23 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2022-03-23 14:53:00   52119   11.343
# 937      Aaron    NaN 1986-01-22 2022-03-23 19:39:00   63126   18.424
# 137       Adam   Male 2011-05-21 2022-03-23 01:45:00   95327   15.120
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services
# 937              False  Client Services
# 137              False     Distribution

# %%
df["Last Login Time"].head()   # wrong datatype showing as object but actual datatype is timedate format
# Out:
# 0    12:42 PM
# 1     6:53 AM
# 2    11:17 AM
# 3     1:00 PM
# 4     4:47 PM
# Name: Last Login Time, dtype: object

# %%
pd.to_datetime(df["Last Login Time"])   # convert from normal time to datetime
# Out:
# 0     2022-03-23 12:42:00
# 1     2022-03-23 06:53:00
# 2     2022-03-23 11:17:00
# 3     2022-03-23 13:00:00
# 4     2022-03-23 16:47:00
#               ...
# 995   2022-03-23 06:09:00
# 996   2022-03-23 06:30:00
# 997   2022-03-23 12:39:00
# 998   2022-03-23 16:45:00
# 999   2022-03-23 18:24:00
# Name: Last Login Time, Length: 1000, dtype: datetime64[ns]

# %%
df["Last Login Time"]=pd.to_datetime(df["Last Login Time"])

# %%
df["Senior Management"]   # wrong data type its shows object but actual datatype is boolean
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999     True
# Name: Senior Management, Length: 1000, dtype: object

# %%
df["Senior Management"].astype("bool")  # convert from object datatype to boolean data type using 'astype' keyword
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999     True
# Name: Senior Management, Length: 1000, dtype: bool

# %%
df["Senior Management"]=df["Senior Management"].astype("bool")

# %%
df["Gender"].head()
# Out:
# 0      Male
# 1      Male
# 2    Female
# 3      Male
# 4      Male
# Name: Gender, dtype: object

# %%
df["Gender"].astype("category")
df["Gender"]=df["Gender"].astype("category")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 41.1+ KB

# %%
# Anotheer Way to change data type 


df=pd.read_csv('employees.csv', parse_dates=["Start Date","Last Login Time"])
df["Senior Management"]=df["Senior Management"].astype("bool")
df["Gender"]=df["Gender"].astype("category")

# %%
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2022-03-23 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2022-03-23 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2022-03-23 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2022-03-23 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2022-03-23 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 41.1+ KB

# %%
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2022-03-23 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2022-03-23 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2022-03-23 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2022-03-23 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2022-03-23 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %% [markdown]
# # Filter DataFrame using & | ! (AND, OR, NOT)

# %%
mask1=df["Gender"]=="Male"

mask2=df["Team"]=="Marketing"

df[mask1 & mask2]
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2022-03-23 12:42:00   97308    6.945
# 21     Matthew   Male 1995-09-05 2022-03-23 02:12:00  100612   13.645
# 26       Craig   Male 2000-02-27 2022-03-23 07:45:00   37598    7.757
# 74      Thomas   Male 1995-06-04 2022-03-23 14:24:00   62096   17.029
# 77     Charles   Male 2004-09-14 2022-03-23 20:13:00  107391    1.260
# 101      Aaron   Male 2012-02-17 2022-03-23 10:20:00   61602   11.849
# 104       John   Male 1989-12-23 2022-03-23 07:01:00   80740   19.305
# 112     Willie   Male 2003-11-27 2022-03-23 06:21:00   64363    4.023
# 119       Paul   Male 2008-06-03 2022-03-23 15:05:00   41054   12.299
# 150       Sean   Male 1996-05-04 2022-03-23 20:59:00  135490   19.934
# 187      Roger   Male 2004-11-19 2022-03-23 15:55:00   51430    6.460
# 204     Willie   Male 2006-06-06 2022-03-23 09:45:00   55281    4.935
# ...

# %%
mask3 = df["Senior Management"]

mask4 = df["Start Date"] < "1990-01-01"

df[mask3 | mask4]             #  |--->> pipe operator
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-03-23 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2022-03-23 06:53:00   61933    4.170
# 3        Jerry    Male 2005-03-04 2022-03-23 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2022-03-23 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2022-03-23 01:35:00  115163   10.125
# ..         ...     ...        ...                 ...     ...      ...
# 992    Anthony    Male 2011-10-16 2022-03-23 08:35:00  112769   11.625
# 993       Tina  Female 1997-05-15 2022-03-23 15:53:00   56450   19.040
# 994     George    Male 2013-06-21 2022-03-23 17:47:00   98874    4.479
# 996    Phillip    Male 1984-01-31 2022-03-23 06:30:00   42392   19.675
# 999     Albert    Male 2012-05-15 2022-03-23 18:24:00  129949   10.169
#
#      Senior Management             Team
# 0                 True        Marketing
# ...

# %%
mask5 = df["First Name"] == "Robert"

mask6 = df["Team"] == "Client Services"

mask7 = df["Start Date"] > "2016-06-01"

df[(mask5 & mask6) | mask7]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 15     Lillian  Female 2016-06-05 2022-03-23 06:09:00   59414    1.256
# 98        Tina  Female 2016-06-16 2022-03-23 19:47:00  100705   16.961
# 387     Robert    Male 1994-10-29 2022-03-23 04:26:00  123294   19.894
# 451      Terry     NaN 2016-07-15 2022-03-23 00:29:00  140002   19.490
#
#      Senior Management             Team
# 15               False          Product
# 98                True        Marketing
# 387              False  Client Services
# 451               True        Marketing

# %%
 df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2022-03-23 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2022-03-23 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2022-03-23 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2022-03-23 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2022-03-23 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %% [markdown]
# # isin() in DataFrame

# %%
mask1= df["Team"] == "Legal"
mask2= df["Team"] == "Sales"
mask3= df["Team"] == "Product"

df[mask1 | mask2 | mask3]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18 2022-03-23 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 2022-03-23 16:20:00   65476   10.012
# 11       Julie  Female 1997-10-26 2022-03-23 15:19:00  102508   12.637
# 13        Gary    Male 2008-01-27 2022-03-23 23:40:00  109831    5.831
# 15     Lillian  Female 2016-06-05 2022-03-23 06:09:00   59414    1.256
# ..         ...     ...        ...                 ...     ...      ...
# 981      James    Male 1993-01-15 2022-03-23 17:19:00  148985   19.280
# 985    Stephen     NaN 1983-07-10 2022-03-23 20:10:00   85668    1.909
# 989     Justin     NaN 1991-02-10 2022-03-23 16:58:00   38344    3.794
# 997    Russell    Male 2013-05-20 2022-03-23 12:39:00   96914    1.421
# 999     Albert    Male 2012-05-15 2022-03-23 18:24:00  129949   10.169
#
#      Senior Management     Team
# 5                False    Legal
# 6                 True  Product
# ...

# %%
# another way using isin() 

df["Team"].isin(["Legal","Sales","Product"])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997     True
# 998    False
# 999     True
# Name: Team, Length: 1000, dtype: bool

# %%
mask=df["Team"].isin(["Legal","Sales","Product"])
df[mask]

df[df["Team"].isin(["Legal","Sales","Product"])]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18 2022-03-23 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 2022-03-23 16:20:00   65476   10.012
# 11       Julie  Female 1997-10-26 2022-03-23 15:19:00  102508   12.637
# 13        Gary    Male 2008-01-27 2022-03-23 23:40:00  109831    5.831
# 15     Lillian  Female 2016-06-05 2022-03-23 06:09:00   59414    1.256
# ..         ...     ...        ...                 ...     ...      ...
# 981      James    Male 1993-01-15 2022-03-23 17:19:00  148985   19.280
# 985    Stephen     NaN 1983-07-10 2022-03-23 20:10:00   85668    1.909
# 989     Justin     NaN 1991-02-10 2022-03-23 16:58:00   38344    3.794
# 997    Russell    Male 2013-05-20 2022-03-23 12:39:00   96914    1.421
# 999     Albert    Male 2012-05-15 2022-03-23 18:24:00  129949   10.169
#
#      Senior Management     Team
# 5                False    Legal
# 6                 True  Product
# ...

# %%
df["Team"].isnull()
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Team, Length: 1000, dtype: bool

# %%
mask=df["Team"].isnull()
df[mask]
# Out:
#       First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1         Thomas    Male 1996-03-31 2022-03-23 06:53:00   61933    4.170
# 10        Louise  Female 1980-08-12 2022-03-23 09:01:00   63241   15.132
# 23           NaN    Male 2012-06-14 2022-03-23 16:19:00  125792    5.042
# 32           NaN    Male 1998-08-21 2022-03-23 14:27:00  122340    6.417
# 91         James     NaN 2005-01-26 2022-03-23 23:00:00  128771    8.309
# 109  Christopher    Male 2000-04-22 2022-03-23 10:15:00   37919   11.449
# 139          NaN  Female 1990-10-03 2022-03-23 01:08:00  132373   10.527
# 199     Jonathan    Male 2009-07-17 2022-03-23 08:15:00  130581   16.736
# 258      Michael    Male 2002-01-24 2022-03-23 03:04:00   43586   12.659
# 290       Jeremy    Male 1988-06-14 2022-03-23 18:20:00  129460   13.657
# 314        Bobby    Male 1996-03-31 2022-03-23 17:40:00  112117    6.338
# 367       Edward    Male 1989-08-04 2022-03-23 06:06:00   66067   10.957
# ...

# %%
df[df["Gender"].notnull()]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-03-23 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2022-03-23 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2022-03-23 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-03-23 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2022-03-23 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 994     George    Male 2013-06-21 2022-03-23 17:47:00   98874    4.479
# 996    Phillip    Male 1984-01-31 2022-03-23 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2022-03-23 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2022-03-23 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2022-03-23 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
df
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-03-23 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2022-03-23 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2022-03-23 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-03-23 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2022-03-23 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2022-03-23 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2022-03-23 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2022-03-23 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2022-03-23 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2022-03-23 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %% [markdown]
# # between() in DataFrame

# %%
df["Salary"].between(60000,70000)
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998     True
# 999    False
# Name: Salary, Length: 1000, dtype: bool

# %%
df[df["Salary"].between(60000,70000)]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2022-03-23 06:53:00   61933    4.170
# 6         Ruby  Female 1987-08-17 2022-03-23 16:20:00   65476   10.012
# 10      Louise  Female 1980-08-12 2022-03-23 09:01:00   63241   15.132
# 20        Lois     NaN 1995-04-22 2022-03-23 19:18:00   64714    4.934
# 41   Christine     NaN 2015-06-28 2022-03-23 01:08:00   66582   11.308
# ..         ...     ...        ...                 ...     ...      ...
# 965  Catherine  Female 1989-09-25 2022-03-23 01:31:00   68164   18.393
# 970      Alice  Female 1988-09-03 2022-03-23 20:54:00   63571   15.397
# 974      Harry    Male 2011-08-30 2022-03-23 18:31:00   67656   16.455
# 978       Sean    Male 1983-01-17 2022-03-23 14:23:00   66146   11.178
# 998      Larry    Male 2013-04-20 2022-03-23 16:45:00   60500   11.985
#
#      Senior Management                  Team
# 1                 True                   NaN
# ...

# %%
df[df["Bonus %"].between(2.0, 5.0)]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2022-03-23 06:53:00   61933    4.170
# 20        Lois     NaN 1995-04-22 2022-03-23 19:18:00   64714    4.934
# 40     Michael    Male 2008-10-10 2022-03-23 11:25:00   99283    2.665
# 49       Chris     NaN 1980-01-24 2022-03-23 12:13:00  113590    3.055
# 60       Paula     NaN 2005-11-23 2022-03-23 14:01:00   48866    4.271
# ..         ...     ...        ...                 ...     ...      ...
# 943      Wayne    Male 2006-09-08 2022-03-23 11:09:00   67471    2.728
# 961    Antonio     NaN 1989-06-18 2022-03-23 21:37:00  103050    3.050
# 976     Denise  Female 1992-10-19 2022-03-23 05:42:00  137954    4.195
# 989     Justin     NaN 1991-02-10 2022-03-23 16:58:00   38344    3.794
# 994     George    Male 2013-06-21 2022-03-23 17:47:00   98874    4.479
#
#      Senior Management          Team
# 1                 True           NaN
# 20                True         Legal
# ...

# %%
df[df["Start Date"].between("1991-01-01","1992-01-01")]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 27       Scott     NaN 1991-07-11 2022-03-23 18:58:00  122367    5.218
# 75      Bonnie  Female 1991-07-02 2022-03-23 01:27:00  104897    5.118
# 88       Donna  Female 1991-11-27 2022-03-23 13:59:00   64088    6.155
# 116        NaN    Male 1991-06-22 2022-03-23 20:58:00   76189   18.988
# 148    Patrick     NaN 1991-07-14 2022-03-23 02:24:00  124488   14.837
# 166        NaN  Female 1991-07-09 2022-03-23 18:52:00   42341    7.014
# 172       Sara  Female 1991-09-23 2022-03-23 18:17:00   97058    9.402
# 220        NaN  Female 1991-06-17 2022-03-23 12:49:00   71945    5.560
# 245     Victor    Male 1991-04-11 2022-03-23 07:44:00   70817   17.138
# 277     Brenda     NaN 1991-05-29 2022-03-23 06:32:00   82439   19.062
# 313       Judy  Female 1991-07-01 2022-03-23 02:33:00  109510   13.457
# 328     Samuel    Male 1991-12-19 2022-03-23 02:54:00   76076    5.319
# ...

# %%
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2022-03-23 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2022-03-23 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2022-03-23 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2022-03-23 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2022-03-23 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
df.sort_values('First Name')
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2022-03-23 10:20:00   61602   11.849
# 327      Aaron    Male 1994-01-29 2022-03-23 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2022-03-23 14:53:00   52119   11.343
# 937      Aaron     NaN 1986-01-22 2022-03-23 19:39:00   63126   18.424
# 137       Adam    Male 2011-05-21 2022-03-23 01:45:00   95327   15.120
# ..         ...     ...        ...                 ...     ...      ...
# 902        NaN    Male 2001-05-23 2022-03-23 19:52:00  103877    6.322
# 925        NaN  Female 2000-08-23 2022-03-23 16:19:00   95866   19.388
# 946        NaN  Female 1985-09-15 2022-03-23 01:50:00  133472   16.941
# 947        NaN    Male 2012-07-30 2022-03-23 15:07:00  107351    5.329
# 951        NaN  Female 2010-09-14 2022-03-23 05:19:00  143638    9.662
#
#      Senior Management             Team
# 101               True        Marketing
# ...

# %%
df=pd.read_csv('employees.csv', parse_dates=["Start Date","Last Login Time"])
df["Senior Management"]=df["Senior Management"].astype("bool")
df["Gender"]=df["Gender"].astype("category")

# %%
df.sort_values("First Name", inplace=True)
df.head()
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2022-03-23 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2022-03-23 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2022-03-23 14:53:00   52119   11.343
# 937      Aaron    NaN 1986-01-22 2022-03-23 19:39:00   63126   18.424
# 137       Adam   Male 2011-05-21 2022-03-23 01:45:00   95327   15.120
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services
# 937              False  Client Services
# 137              False     Distribution

# %%
df["First Name"]
# Out:
# 101    Aaron
# 327    Aaron
# 440    Aaron
# 937    Aaron
# 137     Adam
#        ...
# 902      NaN
# 925      NaN
# 946      NaN
# 947      NaN
# 951      NaN
# Name: First Name, Length: 1000, dtype: object

# %%
df["First Name"].duplicated()
# Out:
# 101    False
# 327     True
# 440     True
# 937     True
# 137    False
#        ...
# 902     True
# 925     True
# 946     True
# 947     True
# 951     True
# Name: First Name, Length: 1000, dtype: bool

# %%
df[df["First Name"].duplicated()]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 327      Aaron    Male 1994-01-29 2022-03-23 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2022-03-23 14:53:00   52119   11.343
# 937      Aaron     NaN 1986-01-22 2022-03-23 19:39:00   63126   18.424
# 141       Adam    Male 1990-12-24 2022-03-23 20:57:00  110194   14.727
# 302       Adam    Male 2007-07-05 2022-03-23 11:59:00   71276    5.027
# ..         ...     ...        ...                 ...     ...      ...
# 902        NaN    Male 2001-05-23 2022-03-23 19:52:00  103877    6.322
# 925        NaN  Female 2000-08-23 2022-03-23 16:19:00   95866   19.388
# 946        NaN  Female 1985-09-15 2022-03-23 01:50:00  133472   16.941
# 947        NaN    Male 2012-07-30 2022-03-23 15:07:00  107351    5.329
# 951        NaN  Female 2010-09-14 2022-03-23 05:19:00  143638    9.662
#
#      Senior Management             Team
# 327               True        Marketing
# ...

# %%
df["First Name"].duplicated(keep='last')
# Out:
# 101     True
# 327     True
# 440     True
# 937    False
# 137     True
#        ...
# 902     True
# 925     True
# 946     True
# 947     True
# 951    False
# Name: First Name, Length: 1000, dtype: bool

# %%
df[df["First Name"].duplicated(keep='last')]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2022-03-23 10:20:00   61602   11.849
# 327      Aaron    Male 1994-01-29 2022-03-23 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2022-03-23 14:53:00   52119   11.343
# 137       Adam    Male 2011-05-21 2022-03-23 01:45:00   95327   15.120
# 141       Adam    Male 1990-12-24 2022-03-23 20:57:00  110194   14.727
# ..         ...     ...        ...                 ...     ...      ...
# 890        NaN    Male 2015-11-24 2022-03-23 03:11:00  145329    7.100
# 902        NaN    Male 2001-05-23 2022-03-23 19:52:00  103877    6.322
# 925        NaN  Female 2000-08-23 2022-03-23 16:19:00   95866   19.388
# 946        NaN  Female 1985-09-15 2022-03-23 01:50:00  133472   16.941
# 947        NaN    Male 2012-07-30 2022-03-23 15:07:00  107351    5.329
#
#      Senior Management             Team
# 101               True        Marketing
# ...

# %%
df["First Name"].duplicated(keep=False)
# Out:
# 101    True
# 327    True
# 440    True
# 937    True
# 137    True
#        ...
# 902    True
# 925    True
# 946    True
# 947    True
# 951    True
# Name: First Name, Length: 1000, dtype: bool

# %%
df[df["First Name"].duplicated(keep=False)]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2022-03-23 10:20:00   61602   11.849
# 327      Aaron    Male 1994-01-29 2022-03-23 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2022-03-23 14:53:00   52119   11.343
# 937      Aaron     NaN 1986-01-22 2022-03-23 19:39:00   63126   18.424
# 137       Adam    Male 2011-05-21 2022-03-23 01:45:00   95327   15.120
# ..         ...     ...        ...                 ...     ...      ...
# 902        NaN    Male 2001-05-23 2022-03-23 19:52:00  103877    6.322
# 925        NaN  Female 2000-08-23 2022-03-23 16:19:00   95866   19.388
# 946        NaN  Female 1985-09-15 2022-03-23 01:50:00  133472   16.941
# 947        NaN    Male 2012-07-30 2022-03-23 15:07:00  107351    5.329
# 951        NaN  Female 2010-09-14 2022-03-23 05:19:00  143638    9.662
#
#      Senior Management             Team
# 101               True        Marketing
# ...

# %%
# to get unique value it wont repeat the value

mask = ~df["First Name"].duplicated(keep=False)

# %%
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22 2022-03-23 06:29:00   95570   18.523
# 688      Brian    Male 2007-04-07 2022-03-23 22:47:00   93901   17.821
# 190      Carol  Female 1996-03-19 2022-03-23 03:39:00   57783    9.129
# 887      David    Male 2009-12-05 2022-03-23 08:48:00   92242   15.407
# 5       Dennis    Male 1987-04-18 2022-03-23 01:35:00  115163   10.125
# 495     Eugene    Male 1984-05-24 2022-03-23 10:54:00   81077    2.117
# 33        Jean  Female 1993-12-18 2022-03-23 09:07:00  119082   16.180
# 832      Keith    Male 2003-02-12 2022-03-23 15:02:00  120672   19.467
# 291      Tammy  Female 1984-11-11 2022-03-23 10:30:00  132839   17.463
#
#      Senior Management                  Team
# 8                 True           Engineering
# 688               True                 Legal
# 190              False               Finance
# 887              False                 Legal
# ...

# %%
df=pd.read_csv('employees.csv', parse_dates=["Start Date","Last Login Time"])
df["Senior Management"]=df["Senior Management"].astype("bool")
df["Gender"]=df["Gender"].astype("category")
df.sort_values("First Name", inplace=True)
df.head()
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2022-03-23 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2022-03-23 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2022-03-23 14:53:00   52119   11.343
# 937      Aaron    NaN 1986-01-22 2022-03-23 19:39:00   63126   18.424
# 137       Adam   Male 2011-05-21 2022-03-23 01:45:00   95327   15.120
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services
# 937              False  Client Services
# 137              False     Distribution

# %%
len(df)
# Out:
# 1000

# %%
len(df.drop_duplicates())
# Out:
# 1000

# %%
df.drop_duplicates(subset=["First Name"],keep="first")
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2022-03-23 10:20:00   61602   11.849
# 137       Adam    Male 2011-05-21 2022-03-23 01:45:00   95327   15.120
# 300       Alan    Male 1988-06-26 2022-03-23 03:54:00  111786    3.592
# 372     Albert    Male 1997-02-01 2022-03-23 16:20:00   67827   19.717
# 988      Alice  Female 2004-10-05 2022-03-23 09:34:00   47638   11.209
# ..         ...     ...        ...                 ...     ...      ...
# 433      Wanda  Female 2008-07-20 2022-03-23 13:44:00   65362    7.132
# 177      Wayne    Male 2012-04-07 2022-03-23 08:00:00  102652   14.085
# 820    William    Male 1993-11-18 2022-03-23 12:27:00   54058    5.182
# 450     Willie    Male 2009-08-22 2022-03-23 13:03:00   55038   19.691
# 7          NaN  Female 2015-07-20 2022-03-23 10:43:00   45906   11.598
#
#      Senior Management             Team
# 101               True        Marketing
# ...

# %%
len(df.drop_duplicates(subset=["First Name"],keep="first"))
# Out:
# 201

# %% [markdown]
# # Sample() Method

# %%
data=pd.read_csv('nba.csv')
data
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
data.sample()
# Out:
#              Name             Team  Number Position   Age Height  Weight  \
# 34  Jose Calderon  New York Knicks     3.0       PG  34.0    6-3   200.0
#
#    College     Salary
# 34     NaN  7402812.0

# %%
data.sample(n=10)
# Out:
#                  Name                    Team  Number Position   Age Height  \
# 428   Al-Farouq Aminu  Portland Trail Blazers     8.0       SF  25.0    6-9
# 157        Taj Gibson           Chicago Bulls    22.0       PF  30.0    6-9
# 396    JaKarr Sampson          Denver Nuggets     9.0       SG  23.0    6-9
# 302  Boban Marjanovic       San Antonio Spurs    40.0        C  27.0    7-3
# 342      Gerald Green              Miami Heat    14.0       SF  30.0    6-7
# 365       Jason Smith           Orlando Magic    14.0       PF  30.0    7-0
# 63    DeMarre Carroll         Toronto Raptors     5.0       SF  29.0    6-8
# 210         Joe Young          Indiana Pacers     1.0       PG  23.0    6-2
# 97     Wesley Johnson    Los Angeles Clippers    33.0       SF  28.0    6-7
# 310  Tim Hardaway Jr.           Atlanta Hawks    10.0       SG  24.0    6-6
#
#      Weight         College      Salary
# 428   215.0     Wake Forest   8042895.0
# 157   225.0             USC   8500000.0
# ...

# %%
data.sample(frac=.25)
# Out:
#                  Name                    Team  Number Position   Age Height  \
# 135     Alan Williams            Phoenix Suns    15.0        C  23.0    6-8
# 453      Shelvin Mack               Utah Jazz     8.0       PG  26.0    6-3
# 1         Jae Crowder          Boston Celtics    99.0       SF  25.0    6-6
# 351  Hassan Whiteside              Miami Heat    21.0        C  26.0    7-0
# 408      Damjan Rudez  Minnesota Timberwolves    10.0       SF  29.0    6-9
# ..                ...                     ...     ...      ...   ...    ...
# 415        Randy Foye   Oklahoma City Thunder     6.0       SG  32.0    6-4
# 366    Nikola Vucevic           Orlando Magic     9.0        C  25.0    7-0
# 149     Eric Moreland        Sacramento Kings    25.0       PF  24.0   6-10
# 27         Henry Sims           Brooklyn Nets    14.0        C  26.0   6-10
# 25        Willie Reed           Brooklyn Nets    33.0       PF  26.0   6-10
#
#      Weight           College      Salary
# ...

# %%
data.sample(axis='columns',n=5)
# Out:
#      Weight Height  Number            Team     Salary
# 0     180.0    6-2     0.0  Boston Celtics  7730337.0
# 1     235.0    6-6    99.0  Boston Celtics  6796117.0
# 2     205.0    6-5    30.0  Boston Celtics        NaN
# 3     185.0    6-5    28.0  Boston Celtics  1148640.0
# 4     231.0   6-10     8.0  Boston Celtics  5000000.0
# ..      ...    ...     ...             ...        ...
# 453   203.0    6-3     8.0       Utah Jazz  2433333.0
# 454   179.0    6-1    25.0       Utah Jazz   900000.0
# 455   256.0    7-3    21.0       Utah Jazz  2900000.0
# 456   231.0    7-0    24.0       Utah Jazz   947276.0
# 457     NaN    NaN     NaN             NaN        NaN
#
# [458 rows x 5 columns]

# %% [markdown]
# # Pandas Concat()

# %%
import pandas as pd

sr1=pd.Series([0,1,2])
sr1
# Out:
# 0    0
# 1    1
# 2    2
# dtype: int64

# %%
sr2=pd.Series([3,4,5])
sr2
# Out:
# 0    3
# 1    4
# 2    5
# dtype: int64

# %%
pd.concat([sr1,sr2])
# Out:
# 0    0
# 1    1
# 2    2
# 0    3
# 1    4
# 2    5
# dtype: int64

# %%
df1=pd.DataFrame({'ID':[1,2,3,4],
              'Name':['A','B','C','D'],
              'Class': [5,6,7,8]})
df1
# Out:
#    ID Name  Class
# 0   1    A      5
# 1   2    B      6
# 2   3    C      7
# 3   4    D      8

# %%
df2=pd.DataFrame({'ID':[5,6,7,8],
              'Name':['E','F','G','H'],
              'Class': [9,10,11,12]})
df2
# Out:
#    ID Name  Class
# 0   5    E      9
# 1   6    F     10
# 2   7    G     11
# 3   8    H     12

# %%
pd.concat([df1,df2])
# Out:
#    ID Name  Class
# 0   1    A      5
# 1   2    B      6
# 2   3    C      7
# 3   4    D      8
# 0   5    E      9
# 1   6    F     10
# 2   7    G     11
# 3   8    H     12

# %%
pd.concat([df2,df1])
# Out:
#    ID Name  Class
# 0   5    E      9
# 1   6    F     10
# 2   7    G     11
# 3   8    H     12
# 0   1    A      5
# 1   2    B      6
# 2   3    C      7
# 3   4    D      8

# %%
pd.concat([df2,df1],axis=1)
# Out:
#    ID Name  Class  ID Name  Class
# 0   5    E      9   1    A      5
# 1   6    F     10   2    B      6
# 2   7    G     11   3    C      7
# 3   8    H     12   4    D      8

# %%
pd.concat([df1,df2],axis=0,ignore_index=True)
# Out:
#    ID Name  Class
# 0   1    A      5
# 1   2    B      6
# 2   3    C      7
# 3   4    D      8
# 4   5    E      9
# 5   6    F     10
# 6   7    G     11
# 7   8    H     12

# %%
df1=pd.DataFrame({'ID':[1,2,3,4],
              'Name':['A','B','C','D'],
              'Class': [5,6,7,8]})
df1
# Out:
#    ID Name  Class
# 0   1    A      5
# 1   2    B      6
# 2   3    C      7
# 3   4    D      8

# %%
df2=pd.DataFrame({'ID':[3,4],
              'Name':['C','D'],
              'Class': [7,8]})
df2
# Out:
#    ID Name  Class
# 0   3    C      7
# 1   4    D      8

# %%
pd.concat([df1,df2],axis=0)
# Out:
#    ID Name  Class
# 0   1    A      5
# 1   2    B      6
# 2   3    C      7
# 3   4    D      8
# 0   3    C      7
# 1   4    D      8

# %%
pd.concat([df1,df2],axis=1)
# Out:
#    ID Name  Class   ID Name  Class
# 0   1    A      5  3.0    C    7.0
# 1   2    B      6  4.0    D    8.0
# 2   3    C      7  NaN  NaN    NaN
# 3   4    D      8  NaN  NaN    NaN

# %%
pd.concat([df1,df2],axis=1,join="inner")
# Out:
#    ID Name  Class  ID Name  Class
# 0   1    A      5   3    C      7
# 1   2    B      6   4    D      8

# %%
pd.concat([df1,df2],keys=['df1','df2'])
# Out:
#        ID Name  Class
# df1 0   1    A      5
#     1   2    B      6
#     2   3    C      7
#     3   4    D      8
# df2 0   3    C      7
#     1   4    D      8

# %%
pd.concat([df1,df2],keys=['First Df','Second Df'])
# Out:
#              ID Name  Class
# First Df  0   1    A      5
#           1   2    B      6
#           2   3    C      7
#           3   4    D      8
# Second Df 0   3    C      7
#           1   4    D      8

# %%
df1=pd.DataFrame({'ID':[1,2,3,4],
              'Name':['A','B','C','D'],
              'Class': [5,6,7,8]})
df1
# Out:
#    ID Name  Class
# 0   1    A      5
# 1   2    B      6
# 2   3    C      7
# 3   4    D      8

# %%
df2=pd.DataFrame({'Marks':[40,63,91,34]})
df2
# Out:
#    Marks
# 0     40
# 1     63
# 2     91
# 3     34

# %%
pd.concat([df1,df2])
# Out:
#     ID Name  Class  Marks
# 0  1.0    A    5.0    NaN
# 1  2.0    B    6.0    NaN
# 2  3.0    C    7.0    NaN
# 3  4.0    D    8.0    NaN
# 0  NaN  NaN    NaN   40.0
# 1  NaN  NaN    NaN   63.0
# 2  NaN  NaN    NaN   91.0
# 3  NaN  NaN    NaN   34.0

# %% [markdown]
# # join Method

# %% [markdown]
# Datafram join is a convenient method for combining the columns of two potentially
# differently-indexed

# %%
import pandas as pd

df1=pd.DataFrame({'A':[1,2,3],
                  'B':[10,20,30]})

df2=pd.DataFrame({'C':[1,2,3],
                  'D':[10,20,30]})

# %%
display(df1,df2)
# Out:
#    A   B
# 0  1  10
# 1  2  20
# 2  3  30
#    C   D
# 0  1  10
# 1  2  20
# 2  3  30

# %%
df1.join(df2)
# Out:
#    A   B  C   D
# 0  1  10  1  10
# 1  2  20  2  20
# 2  3  30  3  30

# %%
df2.join(df1)
# Out:
#    C   D  A   B
# 0  1  10  1  10
# 1  2  20  2  20
# 2  3  30  3  30

# %%
# Suppose index value of both the dataframe is different means?

df1=pd.DataFrame({'A':[1,2,3],
                  'B':[10,20,30]},
                   index=['a','b','c'])


df2=pd.DataFrame({'C':[4,5,6],
                  'D':[40,50,60]})

# %%
display(df1,df2)
# Out:
#    A   B
# a  1  10
# b  2  20
# c  3  30
#    C   D
# 0  4  40
# 1  5  50
# 2  6  60

# %%
df1.join(df2)    # join operation wil not work if both the dataframe index is different
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-120-189116363374> in <module>
# ----> 1 df1.join(df2)    # join operation wil not work if both the dataframe index is different
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    8108         5  K5  A5  NaN
#    8109         """
# -> 8110         return self._join_compat(
#    8111             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    8112         )
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    8133                     sort=sort,
#    8134                 )
# -> 8135             return merge(
#    8136                 self,
#    8137                 other,
#
# ...

# %%
df1=pd.DataFrame({'A':[1,2,3],
                  'B':[10,20,30]},
                   index=['a','b','c'])


df2=pd.DataFrame({'C':[4,5,6],
                  'D':[40,50,60]},
                   index=['a','b','c'])

# %%
display(df1,df2)
# Out:
#    A   B
# a  1  10
# b  2  20
# c  3  30
#    C   D
# a  4  40
# b  5  50
# c  6  60

# %%
df1.join(df2)
# Out:
#    A   B  C   D
# a  1  10  4  40
# b  2  20  5  50
# c  3  30  6  60

# %%
df1=pd.DataFrame({'A':[1,2,3],
                  'B':[10,20,30]},
                   index=['a','b','c'])


df2=pd.DataFrame({'C':[4,5],
                  'D':[40,50]},
                   index=['a','b'])

# %%
display(df1,df2)
# Out:
#    A   B
# a  1  10
# b  2  20
# c  3  30
#    C   D
# a  4  40
# b  5  50

# %%
df1.join(df2)
# Out:
#    A   B    C     D
# a  1  10  4.0  40.0
# b  2  20  5.0  50.0
# c  3  30  NaN   NaN

# %%
df1.join(df2, how='inner')
# Out:
#    A   B  C   D
# a  1  10  4  40
# b  2  20  5  50

# %%
df1.join(df2, how='outer')
# Out:
#    A   B    C     D
# a  1  10  4.0  40.0
# b  2  20  5.0  50.0
# c  3  30  NaN   NaN

# %%
df1.join(df2, how='right')
# Out:
#    A   B  C   D
# a  1  10  4  40
# b  2  20  5  50

# %%
# suppose if both the dataframe column is name what wil happen???

df1=pd.DataFrame({'A':[1,2,3],
                  'B':[10,20,30]},
                   index=['a','b','c'])


df2=pd.DataFrame({'A':[4,5,6],
                  'D':[40,50,60]},
                   index=['a','b','c'])

# %%
df1.join(df2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-110-f8069890b6d0> in <module>
# ----> 1 df1.join(df2)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    8108         5  K5  A5  NaN
#    8109         """
# -> 8110         return self._join_compat(
#    8111             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    8112         )
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    8133                     sort=sort,
#    8134                 )
# -> 8135             return merge(
#    8136                 self,
#    8137                 other,
#
# ...

# %%
# suppose overlapping column to define some new name for that column

df1.join(df2,lsuffix='_A')
# Out:
#    A_A   B  A   D
# a    1  10  4  40
# b    2  20  5  50
# c    3  30  6  60

# %%
df1.join(df2,rsuffix='_A')
# Out:
#    A   B  A_A   D
# a  1  10    4  40
# b  2  20    5  50
# c  3  30    6  60

# %% [markdown]
# # Pivot Table in Pandas

# %% [markdown]
# The levels in the pivot table will be stored in multiindex objects (hierarchical indexes)
# on the index and columns of the result DataFrame

# %%
import pandas as pd

df=pd.read_csv('Movie_Rating.csv')
df

# %%
df.pivot_table(index='Genre')

# %%
df

# %%
df.pivot_table(index='Genre',columns='year')
